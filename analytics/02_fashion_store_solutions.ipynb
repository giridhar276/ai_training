# %% [markdown]
# # Fashion Store - Solution Notebook
#
# Dataset file: `02_fashion_store.csv`

# %% [markdown]
# ## Task 1
#
# Load the dataset into a pandas DataFrame.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('02_fashion_store.csv')
df.head()
# Out:
#       Order_ID  Order_Date Customer_Segment   Region Product_Category  \
# 0  02ORD100522  2025-10-29            Women  Central      Accessories
# 1  02ORD100738  2025-06-21            Women     West      Accessories
# 2  02ORD100741  2024-11-21            Women  Central         Footwear
# 3  02ORD100661  2025-07-05              Men     West            Shirt
# 4  02ORD100412  2025-11-05              Men  Central      Accessories
#
#   Payment_Method  Quantity  Unit_Price  Discount_Percent  Order_Value
# 0            UPI         2     7333.01                14     12612.78
# 1     Debit Card         1     4902.51                18      4020.06
# 2     Debit Card         5     4331.51                21     17109.46
# 3    Credit Card         1     4439.05                46      2397.09
# 4         Wallet         5     7138.56                35     23200.32

# %%
df.dtypes
# Out:
# Order_ID             object
# Order_Date           object
# Customer_Segment     object
# Region               object
# Product_Category     object
# Payment_Method       object
# Quantity              int64
# Unit_Price          float64
# Discount_Percent      int64
# Order_Value         float64
# dtype: object

# %% [markdown]
# ## Task 2
#
# Display the first 10 rows of the DataFrame.

# %%
df.head(10)

# %% [markdown]
# ## Task 3
#
# Display the last 7 rows of the DataFrame.

# %%
df.tail(7)

# %% [markdown]
# ## Task 4
#
# Check the shape of the DataFrame.

# %%
df.shape

# %% [markdown]
# ## Task 5
#
# List all column names.

# %%
df.columns.tolist()

# %% [markdown]
# ## Task 6
#
# Check the data types of all columns.

# %%
df.dtypes

# %% [markdown]
# ## Task 7
#
# Display basic information using info().

# %%
df.info()

# %% [markdown]
# ## Task 8
#
# Generate summary statistics for numerical columns.

# %%
df.describe()

# %% [markdown]
# ## Task 9
#
# Generate summary statistics for categorical columns.

# %%
df.describe(include='object')

# %% [markdown]
# ## Task 10
#
# Check whether the DataFrame contains any missing values.

# %%
df.isna().any()
# Out:
# Order_ID            False
# Order_Date          False
# Customer_Segment    False
# Region              False
# Product_Category    False
# Payment_Method      False
# Quantity            False
# Unit_Price          False
# Discount_Percent    False
# Order_Value         False
# dtype: bool

# %% [markdown]
# ## Task 11
#
# Count the missing values in each column.

# %%
df.isna().sum()
# Out:
# Order_ID            0
# Order_Date          0
# Customer_Segment    0
# Region              0
# Product_Category    0
# Payment_Method      0
# Quantity            0
# Unit_Price          0
# Discount_Percent    0
# Order_Value         0
# dtype: int64

# %% [markdown]
# ## Task 12
#
# Check whether there are any duplicate rows.

# %%
df.duplicated().any()
# Out:
# np.False_

# %%
df.drop_duplicates()

# %% [markdown]
# ## Task 13
#
# Count the duplicate rows in the DataFrame.

# %%
df.duplicated().sum()

# %% [markdown]
# ## Task 14
#
# Drop duplicate rows if any exist.

# %%
df = df.drop_duplicates()
df.shape

# %% [markdown]
# ## Task 15
#
# Convert the Order_Date column to datetime format.

# %%
df['Order_Date'] = pd.to_datetime(df['Order_Date'])
df['Order_Date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order_ID          1000 non-null   object
#  1   Order_Date        1000 non-null   datetime64[ns]
#  2   Customer_Segment  1000 non-null   object
#  3   Region            1000 non-null   object
#  4   Product_Category  1000 non-null   object
#  5   Payment_Method    1000 non-null   object
#  6   Quantity          1000 non-null   int64
#  7   Unit_Price        1000 non-null   float64
#  8   Discount_Percent  1000 non-null   int64
#  9   Order_Value       1000 non-null   float64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(5)
# memory usage: 78.3+ KB

# %%
df
# Out:
#         Order_ID Order_Date Customer_Segment   Region Product_Category  \
# 0    02ORD100522 2025-10-29            Women  Central      Accessories
# 1    02ORD100738 2025-06-21            Women     West      Accessories
# 2    02ORD100741 2024-11-21            Women  Central         Footwear
# 3    02ORD100661 2025-07-05              Men     West            Shirt
# 4    02ORD100412 2025-11-05              Men  Central      Accessories
# ..           ...        ...              ...      ...              ...
# 995  02ORD100107 2025-06-07           Unisex     West            Shirt
# 996  02ORD100271 2025-11-04           Unisex     East            Dress
# 997  02ORD100861 2024-05-04              Men    North            Shirt
# 998  02ORD100436 2025-10-14           Unisex     West      Accessories
# 999  02ORD100103 2024-01-07              Men     East         Footwear
#
#        Payment_Method  Quantity  Unit_Price  Discount_Percent  Order_Value
# 0                 UPI         2     7333.01                14     12612.78
# 1          Debit Card         1     4902.51                18      4020.06
# 2          Debit Card         5     4331.51                21     17109.46
# 3         Credit Card         1     4439.05                46      2397.09
# 4              Wallet         5     7138.56                35     23200.32
# ..                ...       ...         ...               ...          ...
# 995  Cash on Delivery         4     4349.28                20     13917.70
# 996               UPI         1     5492.55                44      3075.83
# 997       Credit Card         1     2148.68                29      1525.56
# 998            Wallet         1      762.39                 0       762.39
# 999  Cash on Delivery         3     5307.28                11     14170.44
#
# [1000 rows x 10 columns]

# %% [markdown]
# ## Task 16
#
# Extract only the year from Order_Date into a new column named Order_Year.

# %%
df['Order_Year'] = df['Order_Date'].dt.year
df[['Order_Date','Order_Year']].head()
# Out:
#   Order_Date  Order_Year
# 0 2025-10-29        2025
# 1 2025-06-21        2025
# 2 2024-11-21        2024
# 3 2025-07-05        2025
# 4 2025-11-05        2025

# %%
df
# Out:
#         Order_ID Order_Date Customer_Segment   Region Product_Category  \
# 0    02ORD100522 2025-10-29            Women  Central      Accessories
# 1    02ORD100738 2025-06-21            Women     West      Accessories
# 2    02ORD100741 2024-11-21            Women  Central         Footwear
# 3    02ORD100661 2025-07-05              Men     West            Shirt
# 4    02ORD100412 2025-11-05              Men  Central      Accessories
# ..           ...        ...              ...      ...              ...
# 995  02ORD100107 2025-06-07           Unisex     West            Shirt
# 996  02ORD100271 2025-11-04           Unisex     East            Dress
# 997  02ORD100861 2024-05-04              Men    North            Shirt
# 998  02ORD100436 2025-10-14           Unisex     West      Accessories
# 999  02ORD100103 2024-01-07              Men     East         Footwear
#
#        Payment_Method  Quantity  Unit_Price  Discount_Percent  Order_Value  \
# 0                 UPI         2     7333.01                14     12612.78
# 1          Debit Card         1     4902.51                18      4020.06
# 2          Debit Card         5     4331.51                21     17109.46
# 3         Credit Card         1     4439.05                46      2397.09
# 4              Wallet         5     7138.56                35     23200.32
# ..                ...       ...         ...               ...          ...
# 995  Cash on Delivery         4     4349.28                20     13917.70
# 996               UPI         1     5492.55                44      3075.83
# 997       Credit Card         1     2148.68                29      1525.56
# 998            Wallet         1      762.39                 0       762.39
# 999  Cash on Delivery         3     5307.28                11     14170.44
#
#      Order_Year
# 0          2025
# 1          2025
# 2          2024
# 3          2025
# 4          2025
# ..          ...
# 995        2025
# 996        2025
# 997        2024
# 998        2025
# 999        2024
#
# [1000 rows x 11 columns]

# %% [markdown]
# ## Task 17
#
# Extract the month name from Order_Date into a new column named Order_Month.

# %%
df['Order_Month'] = df['Order_Date'].dt.month_name()
df[['Order_Date','Order_Month']].head()
# Out:
#   Order_Date Order_Month
# 0 2025-10-29     October
# 1 2025-06-21        June
# 2 2024-11-21    November
# 3 2025-07-05        July
# 4 2025-11-05    November

# %%
df
# Out:
#         Order_ID Order_Date Customer_Segment   Region Product_Category  \
# 0    02ORD100522 2025-10-29            Women  Central      Accessories
# 1    02ORD100738 2025-06-21            Women     West      Accessories
# 2    02ORD100741 2024-11-21            Women  Central         Footwear
# 3    02ORD100661 2025-07-05              Men     West            Shirt
# 4    02ORD100412 2025-11-05              Men  Central      Accessories
# ..           ...        ...              ...      ...              ...
# 995  02ORD100107 2025-06-07           Unisex     West            Shirt
# 996  02ORD100271 2025-11-04           Unisex     East            Dress
# 997  02ORD100861 2024-05-04              Men    North            Shirt
# 998  02ORD100436 2025-10-14           Unisex     West      Accessories
# 999  02ORD100103 2024-01-07              Men     East         Footwear
#
#        Payment_Method  Quantity  Unit_Price  Discount_Percent  Order_Value  \
# 0                 UPI         2     7333.01                14     12612.78
# 1          Debit Card         1     4902.51                18      4020.06
# 2          Debit Card         5     4331.51                21     17109.46
# 3         Credit Card         1     4439.05                46      2397.09
# 4              Wallet         5     7138.56                35     23200.32
# ..                ...       ...         ...               ...          ...
# 995  Cash on Delivery         4     4349.28                20     13917.70
# 996               UPI         1     5492.55                44      3075.83
# 997       Credit Card         1     2148.68                29      1525.56
# 998            Wallet         1      762.39                 0       762.39
# 999  Cash on Delivery         3     5307.28                11     14170.44
#
#      Order_Year Order_Month
# 0          2025     October
# 1          2025        June
# 2          2024    November
# 3          2025        July
# 4          2025    November
# ..          ...         ...
# 995        2025        June
# 996        2025    November
# 997        2024         May
# 998        2025     October
# 999        2024     January
#
# [1000 rows x 12 columns]

# %% [markdown]
# ## Task 18
#
# Extract the weekday name from Order_Date into a new column named Order_Day.

# %%
df['Order_Day'] = df['Order_Date'].dt.day_name()
df[['Order_Date','Order_Day']].head()
# Out:
#   Order_Date  Order_Day
# 0 2025-10-29  Wednesday
# 1 2025-06-21   Saturday
# 2 2024-11-21   Thursday
# 3 2025-07-05   Saturday
# 4 2025-11-05  Wednesday

# %% [markdown]
# ## Task 19
#
# Display a random sample of 12 rows.

# %%
df.sample(12, random_state=42)
# Out:
#         Order_ID Order_Date Customer_Segment   Region Product_Category  \
# 521  02ORD100667 2024-03-23              Men    North            Shirt
# 737  02ORD100130 2025-05-20            Women    South      Accessories
# 740  02ORD100785 2024-04-27             Kids    North            Shirt
# 660  02ORD100153 2025-05-22             Kids     East            Jeans
# 411  02ORD100921 2025-01-10           Unisex     West         Footwear
# 678  02ORD100946 2025-03-13              Men     East            Dress
# 626  02ORD100049 2024-06-17             Kids  Central         Footwear
# 513  02ORD100016 2025-11-17             Kids     East            Jeans
# 859  02ORD100773 2025-08-27            Women  Central      Accessories
# 136  02ORD100121 2024-04-12            Women     West            Jeans
# 811  02ORD100171 2025-04-07            Women  Central         Footwear
# 76   02ORD100653 2025-05-03            Women  Central         Footwear
#
#        Payment_Method  Quantity  Unit_Price  Discount_Percent  Order_Value  \
# 521        Debit Card         1     3765.40                 3      3652.44
# 737               UPI         4     4197.09                 0     16788.36
# 740       Credit Card         1     1013.95                47       537.39
# 660       Credit Card         3     4716.21                38      8772.15
# 411  Cash on Delivery         1      694.58                18       569.56
# 678  Cash on Delivery         1     7708.72                32      5241.93
# 626       Credit Card         1      202.13                27       147.55
# 513            Wallet         3      271.62                34       537.81
# 859       Credit Card         2     3734.44                36      4780.08
# 136  Cash on Delivery         5     2024.65                40      6073.95
# 811        Debit Card         2     2737.26                 4      5255.54
# 76                UPI         1     2896.46                34      1911.66
#
#      Order_Year Order_Month  Order_Day
# 521        2024       March   Saturday
# 737        2025         May    Tuesday
# 740        2024       April   Saturday
# 660        2025         May   Thursday
# 411        2025     January     Friday
# 678        2025       March   Thursday
# 626        2024        June     Monday
# 513        2025    November     Monday
# 859        2025      August  Wednesday
# 136        2024       April     Friday
# 811        2025       April     Monday
# 76         2025         May   Saturday

# %% [markdown]
# ## Task 20
#
# Rename Discount_Percent to Discount.

# %%
df = df.rename(columns={'Discount_Percent':'Discount'})
df.columns.tolist()
# Out:
# ['Order_ID',
#  'Order_Date',
#  'Customer_Segment',
#  'Region',
#  'Product_Category',
#  'Payment_Method',
#  'Quantity',
#  'Unit_Price',
#  'Discount',
#  'Order_Value',
#  'Order_Year',
#  'Order_Month',
#  'Order_Day']

# %% [markdown]
# ## Task 21
#
# Change the column name back from Discount to Discount_Percent.

# %%
df = df.rename(columns={'Discount':'Discount_Percent'})
df.columns.tolist()
# Out:
# ['Order_ID',
#  'Order_Date',
#  'Customer_Segment',
#  'Region',
#  'Product_Category',
#  'Payment_Method',
#  'Quantity',
#  'Unit_Price',
#  'Discount_Percent',
#  'Order_Value',
#  'Order_Year',
#  'Order_Month',
#  'Order_Day']

# %%
df
# Out:
#         Order_ID Order_Date Customer_Segment   Region Product_Category  \
# 0    02ORD100522 2025-10-29            Women  Central      Accessories
# 1    02ORD100738 2025-06-21            Women     West      Accessories
# 2    02ORD100741 2024-11-21            Women  Central         Footwear
# 3    02ORD100661 2025-07-05              Men     West            Shirt
# 4    02ORD100412 2025-11-05              Men  Central      Accessories
# ..           ...        ...              ...      ...              ...
# 995  02ORD100107 2025-06-07           Unisex     West            Shirt
# 996  02ORD100271 2025-11-04           Unisex     East            Dress
# 997  02ORD100861 2024-05-04              Men    North            Shirt
# 998  02ORD100436 2025-10-14           Unisex     West      Accessories
# 999  02ORD100103 2024-01-07              Men     East         Footwear
#
#        Payment_Method  Quantity  Unit_Price  Discount_Percent  Order_Value  \
# 0                 UPI         2     7333.01                14     12612.78
# 1          Debit Card         1     4902.51                18      4020.06
# 2          Debit Card         5     4331.51                21     17109.46
# 3         Credit Card         1     4439.05                46      2397.09
# 4              Wallet         5     7138.56                35     23200.32
# ..                ...       ...         ...               ...          ...
# 995  Cash on Delivery         4     4349.28                20     13917.70
# 996               UPI         1     5492.55                44      3075.83
# 997       Credit Card         1     2148.68                29      1525.56
# 998            Wallet         1      762.39                 0       762.39
# 999  Cash on Delivery         3     5307.28                11     14170.44
#
#      Order_Year Order_Month  Order_Day
# 0          2025     October  Wednesday
# 1          2025        June   Saturday
# 2          2024    November   Thursday
# 3          2025        July   Saturday
# 4          2025    November  Wednesday
# ..          ...         ...        ...
# 995        2025        June   Saturday
# 996        2025    November    Tuesday
# 997        2024         May   Saturday
# 998        2025     October    Tuesday
# 999        2024     January     Sunday
#
# [1000 rows x 13 columns]

# %% [markdown]
# ## Task 22
#
# Set Order_ID as the index.

# %%
df = df.set_index('Order_ID')
df.head()
# Out:
#             Order_Date Customer_Segment   Region Product_Category  \
# Order_ID
# 02ORD100522 2025-10-29            Women  Central      Accessories
# 02ORD100738 2025-06-21            Women     West      Accessories
# 02ORD100741 2024-11-21            Women  Central         Footwear
# 02ORD100661 2025-07-05              Men     West            Shirt
# 02ORD100412 2025-11-05              Men  Central      Accessories
#
#             Payment_Method  Quantity  Unit_Price  Discount_Percent  \
# Order_ID
# 02ORD100522            UPI         2     7333.01                14
# 02ORD100738     Debit Card         1     4902.51                18
# 02ORD100741     Debit Card         5     4331.51                21
# 02ORD100661    Credit Card         1     4439.05                46
# 02ORD100412         Wallet         5     7138.56                35
#
#              Order_Value  Order_Year Order_Month  Order_Day
# Order_ID
# 02ORD100522     12612.78        2025     October  Wednesday
# 02ORD100738      4020.06        2025        June   Saturday
# 02ORD100741     17109.46        2024    November   Thursday
# 02ORD100661      2397.09        2025        July   Saturday
# 02ORD100412     23200.32        2025    November  Wednesday

# %% [markdown]
# ## Task 23
#
# Reset the index back to default integer index.

# %%
df = df.reset_index()
df.head()
# Out:
#       Order_ID Order_Date Customer_Segment   Region Product_Category  \
# 0  02ORD100522 2025-10-29            Women  Central      Accessories
# 1  02ORD100738 2025-06-21            Women     West      Accessories
# 2  02ORD100741 2024-11-21            Women  Central         Footwear
# 3  02ORD100661 2025-07-05              Men     West            Shirt
# 4  02ORD100412 2025-11-05              Men  Central      Accessories
#
#   Payment_Method  Quantity  Unit_Price  Discount_Percent  Order_Value  \
# 0            UPI         2     7333.01                14     12612.78
# 1     Debit Card         1     4902.51                18      4020.06
# 2     Debit Card         5     4331.51                21     17109.46
# 3    Credit Card         1     4439.05                46      2397.09
# 4         Wallet         5     7138.56                35     23200.32
#
#    Order_Year Order_Month  Order_Day
# 0        2025     October  Wednesday
# 1        2025        June   Saturday
# 2        2024    November   Thursday
# 3        2025        July   Saturday
# 4        2025    November  Wednesday

# %% [markdown]
# ## Task 24
#
# Sort the DataFrame by Order_Value in descending order.

# %%
df.sort_values('Order_Value', ascending=False)
# Out:
#         Order_ID Order_Date Customer_Segment   Region Product_Category  \
# 377  02ORD100074 2025-11-23            Women     West      Accessories
# 404  02ORD100619 2024-11-26              Men    North      Accessories
# 275  02ORD100010 2024-10-17            Women     East            Shirt
# 7    02ORD100514 2024-11-28              Men    North            Jeans
# 175  02ORD100364 2025-01-13            Women    South            Jeans
# ..           ...        ...              ...      ...              ...
# 90   02ORD100383 2024-09-13           Unisex  Central            Dress
# 425  02ORD100368 2025-01-01              Men  Central      Accessories
# 617  02ORD100518 2024-08-27              Men    North      Accessories
# 695  02ORD100263 2024-11-16              Men     East         Footwear
# 626  02ORD100049 2024-06-17             Kids  Central         Footwear
#
#        Payment_Method  Quantity  Unit_Price  Discount_Percent  Order_Value  \
# 377  Cash on Delivery         5     7596.72                 6     35704.58
# 404  Cash on Delivery         5     7036.17                 0     35180.85
# 275               UPI         5     7180.66                 6     33749.10
# 7    Cash on Delivery         5     7481.70                15     31797.22
# 175  Cash on Delivery         5     7348.82                14     31599.93
# ..                ...       ...         ...               ...          ...
# 90        Credit Card         1      290.88                29       206.52
# 425        Debit Card         1      209.02                12       183.94
# 617        Debit Card         1      205.16                11       182.59
# 695        Debit Card         1      298.57                43       170.18
# 626       Credit Card         1      202.13                27       147.55
#
#      Order_Year Order_Month  Order_Day
# 377        2025    November     Sunday
# 404        2024    November    Tuesday
# 275        2024     October   Thursday
# 7          2024    November   Thursday
# 175        2025     January     Monday
# ..          ...         ...        ...
# 90         2024   September     Friday
# 425        2025     January  Wednesday
# 617        2024      August    Tuesday
# 695        2024    November   Saturday
# 626        2024        June     Monday
#
# [1000 rows x 13 columns]

# %% [markdown]
# ## Task 25
#
# Sort the DataFrame by Quantity ascending and Unit_Price descending.

# %%
df.sort_values(['Quantity','Unit_Price'], ascending=[True, False])
# Out:
#         Order_ID Order_Date Customer_Segment Region Product_Category  \
# 820  02ORD100241 2025-02-10              Men   West         Footwear
# 327  02ORD100486 2024-08-20            Women  North         Footwear
# 657  02ORD100969 2025-03-01              Men   West            Shirt
# 60   02ORD100297 2025-11-17              Men  South            Shirt
# 488  02ORD100168 2025-02-18            Women   West            Shirt
# ..           ...        ...              ...    ...              ...
# 390  02ORD100186 2025-12-06            Women  North            Jeans
# 358  02ORD100327 2024-10-16              Men  South         Footwear
# 798  02ORD100646 2024-11-10            Women  North            Jeans
# 806  02ORD100699 2025-03-27              Men   East            Jeans
# 812  02ORD100655 2025-11-17             Kids   West            Shirt
#
#        Payment_Method  Quantity  Unit_Price  Discount_Percent  Order_Value  \
# 820            Wallet         1     7990.46                29      5673.23
# 327            Wallet         1     7973.13                24      6059.58
# 657            Wallet         1     7966.26                31      5496.72
# 60         Debit Card         1     7963.77                22      6211.74
# 488               UPI         1     7898.38                38      4897.00
# ..                ...       ...         ...               ...          ...
# 390            Wallet         5      710.69                43      2025.47
# 358  Cash on Delivery         5      676.49                31      2333.89
# 798               UPI         5      630.59                41      1860.24
# 806       Credit Card         5      583.54                13      2538.40
# 812        Debit Card         5      264.92                 2      1298.11
#
#      Order_Year Order_Month  Order_Day
# 820        2025    February     Monday
# 327        2024      August    Tuesday
# 657        2025       March   Saturday
# 60         2025    November     Monday
# 488        2025    February    Tuesday
# ..          ...         ...        ...
# 390        2025    December   Saturday
# 358        2024     October  Wednesday
# 798        2024    November     Sunday
# 806        2025       March   Thursday
# 812        2025    November     Monday
#
# [1000 rows x 13 columns]

# %% [markdown]
# ## Task 26
#
# Filter all rows where Region is North.

# %%
df[df['Region'] == 'North'].head()
# Out:
#        Order_ID Order_Date Customer_Segment Region Product_Category  \
# 6   02ORD100627 2024-11-13           Unisex  North            Shirt
# 7   02ORD100514 2024-11-28              Men  North            Jeans
# 14  02ORD100939 2025-12-15             Kids  North            Jeans
# 17  02ORD100884 2024-11-09             Kids  North      Accessories
# 18  02ORD100762 2025-04-25             Kids  North            Shirt
#
#       Payment_Method  Quantity  Unit_Price  Discount_Percent  Order_Value  \
# 6   Cash on Delivery         1     3627.16                26      2684.10
# 7   Cash on Delivery         5     7481.70                15     31797.22
# 14       Credit Card         1     7554.56                 6      7101.29
# 17  Cash on Delivery         3     3636.89                15      9274.07
# 18  Cash on Delivery         2     7388.47                11     13151.48
#
#     Order_Year Order_Month  Order_Day
# 6         2024    November  Wednesday
# 7         2024    November   Thursday
# 14        2025    December     Monday
# 17        2024    November   Saturday
# 18        2025       April     Friday

# %% [markdown]
# ## Task 27
#
# Filter all rows where Payment_Method is UPI.

# %%
df[df['Payment_Method'] == 'UPI'].head()
# Out:
#        Order_ID Order_Date Customer_Segment   Region Product_Category  \
# 0   02ORD100522 2025-10-29            Women  Central      Accessories
# 10  02ORD100812 2025-10-23            Women     West            Jeans
# 11  02ORD100077 2025-08-11             Kids    South            Shirt
# 13  02ORD100974 2024-02-25           Unisex  Central            Dress
# 20  02ORD100550 2025-01-15            Women    North      Accessories
#
#    Payment_Method  Quantity  Unit_Price  Discount_Percent  Order_Value  \
# 0             UPI         2     7333.01                14     12612.78
# 10            UPI         2     6643.50                23     10230.99
# 11            UPI         4      807.35                 6      3035.64
# 13            UPI         4     4256.25                50      8512.50
# 20            UPI         2     5342.50                27      7800.05
#
#     Order_Year Order_Month  Order_Day
# 0         2025     October  Wednesday
# 10        2025     October   Thursday
# 11        2025      August     Monday
# 13        2024    February     Sunday
# 20        2025     January  Wednesday

# %% [markdown]
# ## Task 28
#
# Filter all rows where Quantity is greater than 3.

# %%
df[df['Quantity'] > 3].head()
# Out:
#        Order_ID Order_Date Customer_Segment   Region Product_Category  \
# 2   02ORD100741 2024-11-21            Women  Central         Footwear
# 4   02ORD100412 2025-11-05              Men  Central      Accessories
# 7   02ORD100514 2024-11-28              Men    North            Jeans
# 11  02ORD100077 2025-08-11             Kids    South            Shirt
# 13  02ORD100974 2024-02-25           Unisex  Central            Dress
#
#       Payment_Method  Quantity  Unit_Price  Discount_Percent  Order_Value  \
# 2         Debit Card         5     4331.51                21     17109.46
# 4             Wallet         5     7138.56                35     23200.32
# 7   Cash on Delivery         5     7481.70                15     31797.22
# 11               UPI         4      807.35                 6      3035.64
# 13               UPI         4     4256.25                50      8512.50
#
#     Order_Year Order_Month  Order_Day
# 2         2024    November   Thursday
# 4         2025    November  Wednesday
# 7         2024    November   Thursday
# 11        2025      August     Monday
# 13        2024    February     Sunday

# %% [markdown]
# ## Task 29
#
# Filter all rows where Order_Value is above 5000.

# %%
df[df['Order_Value'] > 5000].head()
# Out:
#       Order_ID Order_Date Customer_Segment   Region Product_Category  \
# 0  02ORD100522 2025-10-29            Women  Central      Accessories
# 2  02ORD100741 2024-11-21            Women  Central         Footwear
# 4  02ORD100412 2025-11-05              Men  Central      Accessories
# 5  02ORD100679 2024-05-08              Men     East            Jeans
# 7  02ORD100514 2024-11-28              Men    North            Jeans
#
#      Payment_Method  Quantity  Unit_Price  Discount_Percent  Order_Value  \
# 0               UPI         2     7333.01                14     12612.78
# 2        Debit Card         5     4331.51                21     17109.46
# 4            Wallet         5     7138.56                35     23200.32
# 5       Credit Card         3     3642.97                43      6229.48
# 7  Cash on Delivery         5     7481.70                15     31797.22
#
#    Order_Year Order_Month  Order_Day
# 0        2025     October  Wednesday
# 2        2024    November   Thursday
# 4        2025    November  Wednesday
# 5        2024         May  Wednesday
# 7        2024    November   Thursday

# %% [markdown]
# ## Task 30
#
# Filter rows where Discount_Percent is between 10 and 20.

# %%
df[df['Discount_Percent'].between(10,20)].head()
# Out:
#        Order_ID Order_Date Customer_Segment   Region Product_Category  \
# 0   02ORD100522 2025-10-29            Women  Central      Accessories
# 1   02ORD100738 2025-06-21            Women     West      Accessories
# 7   02ORD100514 2024-11-28              Men    North            Jeans
# 17  02ORD100884 2024-11-09             Kids    North      Accessories
# 18  02ORD100762 2025-04-25             Kids    North            Shirt
#
#       Payment_Method  Quantity  Unit_Price  Discount_Percent  Order_Value  \
# 0                UPI         2     7333.01                14     12612.78
# 1         Debit Card         1     4902.51                18      4020.06
# 7   Cash on Delivery         5     7481.70                15     31797.22
# 17  Cash on Delivery         3     3636.89                15      9274.07
# 18  Cash on Delivery         2     7388.47                11     13151.48
#
#     Order_Year Order_Month  Order_Day
# 0         2025     October  Wednesday
# 1         2025        June   Saturday
# 7         2024    November   Thursday
# 17        2024    November   Saturday
# 18        2025       April     Friday

# %% [markdown]
# ## Task 31
#
# Filter rows where Product_Category belongs to a given list of two categories.

# %%
df['Product_Category'].unique()[:2]
# Out:
# array(['Accessories', 'Footwear'], dtype=object)

# %%
df[df['Product_Category'].isin(df['Product_Category'].unique()[:2])].head()
# Out:
#       Order_ID Order_Date Customer_Segment   Region Product_Category  \
# 0  02ORD100522 2025-10-29            Women  Central      Accessories
# 1  02ORD100738 2025-06-21            Women     West      Accessories
# 2  02ORD100741 2024-11-21            Women  Central         Footwear
# 4  02ORD100412 2025-11-05              Men  Central      Accessories
# 9  02ORD100137 2024-09-29              Men     West         Footwear
#
#   Payment_Method  Quantity  Unit_Price  Discount_Percent  Order_Value  \
# 0            UPI         2     7333.01                14     12612.78
# 1     Debit Card         1     4902.51                18      4020.06
# 2     Debit Card         5     4331.51                21     17109.46
# 4         Wallet         5     7138.56                35     23200.32
# 9    Credit Card         2      528.16                30       739.42
#
#    Order_Year Order_Month  Order_Day
# 0        2025     October  Wednesday
# 1        2025        June   Saturday
# 2        2024    November   Thursday
# 4        2025    November  Wednesday
# 9        2024   September     Sunday

# %% [markdown]
# ## Task 32
#
# Find all unique values in Customer_Segment.

# %%
df['Customer_Segment'].unique()
# Out:
# array(['Women', 'Men', 'Unisex', 'Kids'], dtype=object)

# %% [markdown]
# ## Task 33
#
# Count the number of unique values in Product_Category.

# %%
df['Product_Category'].nunique()
# Out:
# 5

# %% [markdown]
# ## Task 34
#
# Display value counts for Region.

# %%
df['Region'].value_counts()
# Out:
# Region
# West       213
# South      212
# Central    203
# North      196
# East       176
# Name: count, dtype: int64

# %% [markdown]
# ## Task 35
#
# Display value counts for Payment_Method.

# %%
df['Payment_Method'].value_counts()
# Out:
# Payment_Method
# Credit Card         214
# Wallet              205
# Cash on Delivery    204
# UPI                 192
# Debit Card          185
# Name: count, dtype: int64

# %% [markdown]
# ## Task 36
#
# Find the minimum, maximum, and mean of Unit_Price.

# %%
df['Unit_Price'].agg(['min','max','mean'])
# Out:
# min      200.89000
# max     7990.46000
# mean    3935.16064
# Name: Unit_Price, dtype: float64

# %% [markdown]
# ## Task 37
#
# Find the total sum of Order_Value.

# %%
df['Order_Value'].sum()
# Out:
# np.float64(7051371.359999999)

# %% [markdown]
# ## Task 38
#
# Find the median of Quantity.

# %%
df['Quantity'].median()
# Out:
# np.float64(2.0)

# %% [markdown]
# ## Task 39
#
# Find the standard deviation of Order_Value.

# %%
df['Order_Value'].std()
# Out:
# np.float64(6625.001269025715)

# %% [markdown]
# ## Task 40
#
# Create a new column Gross_Value as Quantity multiplied by Unit_Price.

# %%
df['Gross_Value'] = df['Quantity'] * df['Unit_Price']
df[['Quantity','Unit_Price','Gross_Value']].head()
# Out:
#    Quantity  Unit_Price  Gross_Value
# 0         2     7333.01     14666.02
# 1         1     4902.51      4902.51
# 2         5     4331.51     21657.55
# 3         1     4439.05      4439.05
# 4         5     7138.56     35692.80

# %% [markdown]
# ## Task 41
#
# Verify whether Gross_Value and Order_Value are consistent after discount calculation.

# %%
df['Expected_Order_Value'] = (df['Gross_Value'] * (1 - df['Discount_Percent']/100)).round(2)
(df['Expected_Order_Value'] == df['Order_Value']).value_counts()
# Out:
# True    1000
# Name: count, dtype: int64

# %% [markdown]
# ## Task 42
#
# Create a new column Discount_Amount.

# %%
df['Discount_Amount'] = (df['Gross_Value'] - df['Order_Value']).round(2)
df[['Gross_Value','Order_Value','Discount_Amount']].head()
# Out:
#    Gross_Value  Order_Value  Discount_Amount
# 0     14666.02     12612.78          2053.24
# 1      4902.51      4020.06           882.45
# 2     21657.55     17109.46          4548.09
# 3      4439.05      2397.09          2041.96
# 4     35692.80     23200.32         12492.48

# %% [markdown]
# ## Task 43
#
# Create a new column High_Value_Order where Order_Value > 5000 is Yes otherwise No.

# %%
df['High_Value_Order'] = np.where(df['Order_Value'] > 5000, 'Yes', 'No')
df[['Order_Value','High_Value_Order']].head()
# Out:
#    Order_Value High_Value_Order
# 0     12612.78              Yes
# 1      4020.06               No
# 2     17109.46              Yes
# 3      2397.09               No
# 4     23200.32              Yes

# %% [markdown]
# ## Task 44
#
# Use apply() to categorize Unit_Price into Low, Medium, High.

# %%
df
# Out:
#         Order_ID Order_Date Customer_Segment   Region Product_Category  \
# 0    02ORD100522 2025-10-29            Women  Central      Accessories
# 1    02ORD100738 2025-06-21            Women     West      Accessories
# 2    02ORD100741 2024-11-21            Women  Central         Footwear
# 3    02ORD100661 2025-07-05              Men     West            Shirt
# 4    02ORD100412 2025-11-05              Men  Central      Accessories
# ..           ...        ...              ...      ...              ...
# 995  02ORD100107 2025-06-07           Unisex     West            Shirt
# 996  02ORD100271 2025-11-04           Unisex     East            Dress
# 997  02ORD100861 2024-05-04              Men    North            Shirt
# 998  02ORD100436 2025-10-14           Unisex     West      Accessories
# 999  02ORD100103 2024-01-07              Men     East         Footwear
#
#        Payment_Method  Quantity  Unit_Price  Discount_Percent  Order_Value  \
# 0                 UPI         2     7333.01                14     12612.78
# 1          Debit Card         1     4902.51                18      4020.06
# 2          Debit Card         5     4331.51                21     17109.46
# 3         Credit Card         1     4439.05                46      2397.09
# 4              Wallet         5     7138.56                35     23200.32
# ..                ...       ...         ...               ...          ...
# 995  Cash on Delivery         4     4349.28                20     13917.70
# 996               UPI         1     5492.55                44      3075.83
# 997       Credit Card         1     2148.68                29      1525.56
# 998            Wallet         1      762.39                 0       762.39
# 999  Cash on Delivery         3     5307.28                11     14170.44
#
#      Order_Year Order_Month  Order_Day  Gross_Value  Expected_Order_Value  \
# 0          2025     October  Wednesday     14666.02              12612.78
# 1          2025        June   Saturday      4902.51               4020.06
# 2          2024    November   Thursday     21657.55              17109.46
# 3          2025        July   Saturday      4439.05               2397.09
# 4          2025    November  Wednesday     35692.80              23200.32
# ..          ...         ...        ...          ...                   ...
# 995        2025        June   Saturday     17397.12              13917.70
# 996        2025    November    Tuesday      5492.55               3075.83
# 997        2024         May   Saturday      2148.68               1525.56
# 998        2025     October    Tuesday       762.39                762.39
# 999        2024     January     Sunday     15921.84              14170.44
#
#      Discount_Amount High_Value_Order
# 0            2053.24              Yes
# 1             882.45               No
# 2            4548.09              Yes
# 3            2041.96               No
# 4           12492.48              Yes
# ..               ...              ...
# 995          3479.42              Yes
# 996          2416.72               No
# 997           623.12               No
# 998             0.00               No
# 999          1751.40              Yes
#
# [1000 rows x 17 columns]

# %%
def price_band(x):
    if x < df['Unit_Price'].quantile(0.33):
        return 'Low'
    elif x < df['Unit_Price'].quantile(0.66):
        return 'Medium'
    return 'High'

df['Price_Band'] = df['Unit_Price'].apply(price_band)
df[['Unit_Price','Price_Band']].head()
# Out:
#    Unit_Price Price_Band
# 0     7333.01       High
# 1     4902.51     Medium
# 2     4331.51     Medium
# 3     4439.05     Medium
# 4     7138.56       High

# %% [markdown]
# ## Task 45
#
# Find the top 10 highest Order_Value rows.

# %%
df.nlargest(10, 'Order_Value')
# Out:
#         Order_ID Order_Date Customer_Segment Region Product_Category  \
# 377  02ORD100074 2025-11-23            Women   West      Accessories
# 404  02ORD100619 2024-11-26              Men  North      Accessories
# 275  02ORD100010 2024-10-17            Women   East            Shirt
# 7    02ORD100514 2024-11-28              Men  North            Jeans
# 175  02ORD100364 2025-01-13            Women  South            Jeans
# 328  02ORD100712 2025-11-01            Women   East            Shirt
# 240  02ORD100004 2025-11-11              Men  South         Footwear
# 129  02ORD100801 2025-06-03           Unisex  North            Dress
# 934  02ORD100014 2024-07-23              Men  South      Accessories
# 148  02ORD100823 2024-05-31             Kids  North      Accessories
#
#        Payment_Method  Quantity  Unit_Price  Discount_Percent  Order_Value  \
# 377  Cash on Delivery         5     7596.72                 6     35704.58
# 404  Cash on Delivery         5     7036.17                 0     35180.85
# 275               UPI         5     7180.66                 6     33749.10
# 7    Cash on Delivery         5     7481.70                15     31797.22
# 175  Cash on Delivery         5     7348.82                14     31599.93
# 328       Credit Card         5     6855.10                 9     31190.70
# 240       Credit Card         5     7513.10                18     30803.71
# 129       Credit Card         5     6222.47                 1     30801.23
# 934        Debit Card         4     7588.94                 0     30355.76
# 148        Debit Card         5     6868.85                13     29879.50
#
#      Order_Year Order_Month Order_Day  Gross_Value  Expected_Order_Value  \
# 377        2025    November    Sunday     37983.60              35704.58
# 404        2024    November   Tuesday     35180.85              35180.85
# 275        2024     October  Thursday     35903.30              33749.10
# 7          2024    November  Thursday     37408.50              31797.22
# 175        2025     January    Monday     36744.10              31599.93
# 328        2025    November  Saturday     34275.50              31190.70
# 240        2025    November   Tuesday     37565.50              30803.71
# 129        2025        June   Tuesday     31112.35              30801.23
# 934        2024        July   Tuesday     30355.76              30355.76
# 148        2024         May    Friday     34344.25              29879.50
#
#      Discount_Amount High_Value_Order Price_Band
# 377          2279.02              Yes       High
# 404             0.00              Yes       High
# 275          2154.20              Yes       High
# 7            5611.28              Yes       High
# 175          5144.17              Yes       High
# 328          3084.80              Yes       High
# 240          6761.79              Yes       High
# 129           311.12              Yes       High
# 934             0.00              Yes       High
# 148          4464.75              Yes       High

# %% [markdown]
# ## Task 46
#
# Find the bottom 10 lowest Order_Value rows.

# %%
df.nsmallest(10, 'Order_Value')
# Out:
#         Order_ID Order_Date Customer_Segment   Region Product_Category  \
# 626  02ORD100049 2024-06-17             Kids  Central         Footwear
# 695  02ORD100263 2024-11-16              Men     East         Footwear
# 617  02ORD100518 2024-08-27              Men    North      Accessories
# 425  02ORD100368 2025-01-01              Men  Central      Accessories
# 90   02ORD100383 2024-09-13           Unisex  Central            Dress
# 697  02ORD100298 2024-10-08           Unisex    South            Shirt
# 961  02ORD100561 2025-01-10              Men  Central         Footwear
# 647  02ORD100851 2024-06-03              Men     West      Accessories
# 744  02ORD100220 2025-06-04            Women     West         Footwear
# 270  02ORD100491 2024-10-18              Men    North            Jeans
#
#        Payment_Method  Quantity  Unit_Price  Discount_Percent  Order_Value  \
# 626       Credit Card         1      202.13                27       147.55
# 695        Debit Card         1      298.57                43       170.18
# 617        Debit Card         1      205.16                11       182.59
# 425        Debit Card         1      209.02                12       183.94
# 90        Credit Card         1      290.88                29       206.52
# 697               UPI         1      375.03                43       213.77
# 961  Cash on Delivery         1      399.79                42       231.88
# 647        Debit Card         1      314.88                26       233.01
# 744  Cash on Delivery         1      378.77                36       242.41
# 270            Wallet         1      441.24                42       255.92
#
#      Order_Year Order_Month  Order_Day  Gross_Value  Expected_Order_Value  \
# 626        2024        June     Monday       202.13                147.55
# 695        2024    November   Saturday       298.57                170.18
# 617        2024      August    Tuesday       205.16                182.59
# 425        2025     January  Wednesday       209.02                183.94
# 90         2024   September     Friday       290.88                206.52
# 697        2024     October    Tuesday       375.03                213.77
# 961        2025     January     Friday       399.79                231.88
# 647        2024        June     Monday       314.88                233.01
# 744        2025        June  Wednesday       378.77                242.41
# 270        2024     October     Friday       441.24                255.92
#
#      Discount_Amount High_Value_Order Price_Band
# 626            54.58               No        Low
# 695           128.39               No        Low
# 617            22.57               No        Low
# 425            25.08               No        Low
# 90             84.36               No        Low
# 697           161.26               No        Low
# 961           167.91               No        Low
# 647            81.87               No        Low
# 744           136.36               No        Low
# 270           185.32               No        Low

# %% [markdown]
# ## Task 47
#
# Group by Region and calculate average Order_Value.

# %%
df.groupby('Region')['Order_Value'].mean().sort_values(ascending=False)
# Out:
# Region
# East       7425.817955
# Central    7158.560099
# North      6973.659133
# West       6896.647840
# South      6865.172264
# Name: Order_Value, dtype: float64

# %% [markdown]
# ## Task 48
#
# Group by Product_Category and calculate total sales.

# %%
df.groupby('Product_Category')['Order_Value'].sum().sort_values(ascending=False)
# Out:
# Product_Category
# Jeans          1495690.89
# Shirt          1411885.70
# Accessories    1395443.67
# Dress          1388871.20
# Footwear       1359479.90
# Name: Order_Value, dtype: float64

# %% [markdown]
# ## Task 49
#
# Group by Payment_Method and calculate total Quantity sold.

# %%
df.groupby('Payment_Method')['Quantity'].sum().sort_values(ascending=False)
# Out:
# Payment_Method
# Credit Card         503
# Wallet              489
# UPI                 465
# Cash on Delivery    460
# Debit Card          432
# Name: Quantity, dtype: int64

# %% [markdown]
# ## Task 50
#
# Group by Customer_Segment and calculate average discount percentage.

# %%
df.groupby('Customer_Segment')['Discount_Percent'].mean().sort_values(ascending=False)
# Out:
# Customer_Segment
# Women     25.150407
# Unisex    25.071161
# Men       24.824000
# Kids      24.345992
# Name: Discount_Percent, dtype: float64

# %% [markdown]
# ## Task 51
#
# Perform multi-level grouping by Region and Product_Category and compute total Order_Value.

# %%
df.groupby(['Region','Product_Category'])['Order_Value'].sum().sort_values(ascending=False)
# Out:
# Region   Product_Category
# East     Shirt               409151.97
# West     Accessories         365052.76
# North    Footwear            345624.11
# Central  Accessories         328508.52
# North    Jeans               323572.56
# South    Accessories         314701.61
#          Jeans               314507.26
#          Dress               312450.10
# Central  Footwear            307405.96
# West     Shirt               306403.38
# Central  Shirt               298509.34
# West     Jeans               293570.77
# Central  Jeans               293285.37
# West     Dress               289757.73
# North    Dress               288949.82
# East     Dress               272235.04
#          Jeans               270754.93
# South    Footwear            265076.47
# North    Accessories         259550.77
# South    Shirt               248681.08
# East     Footwear            227172.01
# Central  Dress               225478.51
# West     Footwear            214201.35
# North    Shirt               149139.93
# East     Accessories         127630.01
# Name: Order_Value, dtype: float64

# %% [markdown]
# ## Task 52
#
# Aggregate Quantity, Unit_Price, and Order_Value with multiple statistics using agg().

# %%
df[['Quantity','Unit_Price','Order_Value']].agg(['min','max','mean','sum'])
# Out:
#       Quantity    Unit_Price   Order_Value
# min      1.000  2.008900e+02  1.475500e+02
# max      5.000  7.990460e+03  3.570458e+04
# mean     2.349  3.935161e+03  7.051371e+03
# sum   2349.000  3.935161e+06  7.051371e+06

# %% [markdown]
# ## Task 53
#
# Create a pivot table showing total Order_Value by Region and Payment_Method.

# %%
pd.pivot_table(df, values='Order_Value', index='Region', columns='Payment_Method', aggfunc='sum', fill_value=0)
# Out:
# Payment_Method  Cash on Delivery  Credit Card  Debit Card        UPI  \
# Region
# Central                278788.23    347114.33   251713.36  285067.39
# East                   239172.26    278139.46   232074.52  363406.13
# North                  291316.09    200642.04   298092.47  206533.64
# South                  316539.94    303987.07   280234.75  261288.58
# West                   250947.67    383356.75   271655.75  288881.66
#
# Payment_Method     Wallet
# Region
# Central         290504.39
# East            194151.59
# North           370252.95
# South           293366.18
# West            274144.16

# %% [markdown]
# ## Task 54
#
# Create a pivot table showing average Unit_Price by Product_Category and Customer_Segment.

# %%
pd.pivot_table(df, values='Unit_Price', index='Product_Category', columns='Customer_Segment', aggfunc='mean', fill_value=0)
# Out:
# Customer_Segment         Kids          Men       Unisex        Women
# Product_Category
# Accessories       4122.765098  4091.577027  4430.102500  4085.443725
# Dress             3732.416471  3811.713542  4013.775833  3578.945769
# Footwear          3718.680800  3660.416897  3825.591333  4416.137115
# Jeans             3488.910682  4062.896667  3619.695082  4064.718750
# Shirt             3969.591207  3950.019787  3831.454898  4212.579767

# %% [markdown]
# ## Task 55
#
# Count the number of orders placed in each month.

# %%
df
# Out:
#         Order_ID Order_Date Customer_Segment   Region Product_Category  \
# 0    02ORD100522 2025-10-29            Women  Central      Accessories
# 1    02ORD100738 2025-06-21            Women     West      Accessories
# 2    02ORD100741 2024-11-21            Women  Central         Footwear
# 3    02ORD100661 2025-07-05              Men     West            Shirt
# 4    02ORD100412 2025-11-05              Men  Central      Accessories
# ..           ...        ...              ...      ...              ...
# 995  02ORD100107 2025-06-07           Unisex     West            Shirt
# 996  02ORD100271 2025-11-04           Unisex     East            Dress
# 997  02ORD100861 2024-05-04              Men    North            Shirt
# 998  02ORD100436 2025-10-14           Unisex     West      Accessories
# 999  02ORD100103 2024-01-07              Men     East         Footwear
#
#        Payment_Method  Quantity  Unit_Price  Discount_Percent  Order_Value  \
# 0                 UPI         2     7333.01                14     12612.78
# 1          Debit Card         1     4902.51                18      4020.06
# 2          Debit Card         5     4331.51                21     17109.46
# 3         Credit Card         1     4439.05                46      2397.09
# 4              Wallet         5     7138.56                35     23200.32
# ..                ...       ...         ...               ...          ...
# 995  Cash on Delivery         4     4349.28                20     13917.70
# 996               UPI         1     5492.55                44      3075.83
# 997       Credit Card         1     2148.68                29      1525.56
# 998            Wallet         1      762.39                 0       762.39
# 999  Cash on Delivery         3     5307.28                11     14170.44
#
#      Order_Year Order_Month  Order_Day  Gross_Value  Expected_Order_Value  \
# 0          2025     October  Wednesday     14666.02              12612.78
# 1          2025        June   Saturday      4902.51               4020.06
# 2          2024    November   Thursday     21657.55              17109.46
# 3          2025        July   Saturday      4439.05               2397.09
# 4          2025    November  Wednesday     35692.80              23200.32
# ..          ...         ...        ...          ...                   ...
# 995        2025        June   Saturday     17397.12              13917.70
# 996        2025    November    Tuesday      5492.55               3075.83
# 997        2024         May   Saturday      2148.68               1525.56
# 998        2025     October    Tuesday       762.39                762.39
# 999        2024     January     Sunday     15921.84              14170.44
#
#      Discount_Amount High_Value_Order Price_Band
# 0            2053.24              Yes       High
# 1             882.45               No     Medium
# 2            4548.09              Yes     Medium
# 3            2041.96               No     Medium
# 4           12492.48              Yes       High
# ..               ...              ...        ...
# 995          3479.42              Yes     Medium
# 996          2416.72               No       High
# 997           623.12               No        Low
# 998             0.00               No        Low
# 999          1751.40              Yes       High
#
# [1000 rows x 18 columns]

# %%
df.groupby(df['Order_Date'].dt.month_name())['Order_ID'].count()
# Out:
# Order_Date
# April         85
# August       103
# December      81
# February      75
# January       95
# July          77
# June          74
# March         79
# May           76
# November      88
# October       94
# September     73
# Name: Order_ID, dtype: int64

# %% [markdown]
# ## Task 56
#
# Find the month with the highest total sales.

# %%
monthly_sales = df.groupby(df['Order_Date'].dt.month_name())['Order_Value'].sum()
monthly_sales.sort_values(ascending=False).head(1)
# Out:
# Order_Date
# November    727198.6
# Name: Order_Value, dtype: float64

# %% [markdown]
# ## Task 57
#
# Find the region with the highest average order value.

# %%
df.groupby('Region')['Order_Value'].mean().sort_values(ascending=False).head(1)
# Out:
# Region
# East    7425.817955
# Name: Order_Value, dtype: float64

# %% [markdown]
# ## Task 58
#
# Find the product category with the highest total quantity sold.

# %%
df.groupby('Product_Category')['Quantity'].sum().sort_values(ascending=False).head(1)
# Out:
# Product_Category
# Jeans    512
# Name: Quantity, dtype: int64

# %% [markdown]
# ## Task 59
#
# Use query() to filter rows where Quantity >= 2 and Discount_Percent >= 15.

# %%
df.query('Quantity >= 2 and Discount_Percent >= 15').head()
# Out:
#       Order_ID Order_Date Customer_Segment   Region Product_Category  \
# 2  02ORD100741 2024-11-21            Women  Central         Footwear
# 4  02ORD100412 2025-11-05              Men  Central      Accessories
# 5  02ORD100679 2024-05-08              Men     East            Jeans
# 7  02ORD100514 2024-11-28              Men    North            Jeans
# 9  02ORD100137 2024-09-29              Men     West         Footwear
#
#      Payment_Method  Quantity  Unit_Price  Discount_Percent  Order_Value  \
# 2        Debit Card         5     4331.51                21     17109.46
# 4            Wallet         5     7138.56                35     23200.32
# 5       Credit Card         3     3642.97                43      6229.48
# 7  Cash on Delivery         5     7481.70                15     31797.22
# 9       Credit Card         2      528.16                30       739.42
#
#    Order_Year Order_Month  Order_Day  Gross_Value  Expected_Order_Value  \
# 2        2024    November   Thursday     21657.55              17109.46
# 4        2025    November  Wednesday     35692.80              23200.32
# 5        2024         May  Wednesday     10928.91               6229.48
# 7        2024    November   Thursday     37408.50              31797.22
# 9        2024   September     Sunday      1056.32                739.42
#
#    Discount_Amount High_Value_Order Price_Band
# 2          4548.09              Yes     Medium
# 4         12492.48              Yes       High
# 5          4699.43              Yes     Medium
# 7          5611.28              Yes       High
# 9           316.90               No        Low

# %% [markdown]
# ## Task 60
#
# Select only Order_ID, Region, Product_Category, and Order_Value columns.

# %%
df[['Order_ID','Region','Product_Category','Order_Value']].head()
# Out:
#       Order_ID   Region Product_Category  Order_Value
# 0  02ORD100522  Central      Accessories     12612.78
# 1  02ORD100738     West      Accessories      4020.06
# 2  02ORD100741  Central         Footwear     17109.46
# 3  02ORD100661     West            Shirt      2397.09
# 4  02ORD100412  Central      Accessories     23200.32

# %% [markdown]
# ## Task 61
#
# Reorder the columns in any meaningful custom order.

# %%
df[['Order_ID','Order_Date','Region','Customer_Segment','Product_Category','Payment_Method','Quantity','Unit_Price','Discount_Percent','Order_Value']].head()
# Out:
#       Order_ID Order_Date   Region Customer_Segment Product_Category  \
# 0  02ORD100522 2025-10-29  Central            Women      Accessories
# 1  02ORD100738 2025-06-21     West            Women      Accessories
# 2  02ORD100741 2024-11-21  Central            Women         Footwear
# 3  02ORD100661 2025-07-05     West              Men            Shirt
# 4  02ORD100412 2025-11-05  Central              Men      Accessories
#
#   Payment_Method  Quantity  Unit_Price  Discount_Percent  Order_Value
# 0            UPI         2     7333.01                14     12612.78
# 1     Debit Card         1     4902.51                18      4020.06
# 2     Debit Card         5     4331.51                21     17109.46
# 3    Credit Card         1     4439.05                46      2397.09
# 4         Wallet         5     7138.56                35     23200.32

# %% [markdown]
# ## Task 62
#
# Find rows where Order_Value is above the overall average order value.

# %%
df['Order_Value'].mean()
# Out:
# np.float64(7051.371359999999)

# %%
df[df['Order_Value'] > df['Order_Value'].mean()].head()
# Out:
#        Order_ID Order_Date Customer_Segment   Region Product_Category  \
# 0   02ORD100522 2025-10-29            Women  Central      Accessories
# 2   02ORD100741 2024-11-21            Women  Central         Footwear
# 4   02ORD100412 2025-11-05              Men  Central      Accessories
# 7   02ORD100514 2024-11-28              Men    North            Jeans
# 10  02ORD100812 2025-10-23            Women     West            Jeans
#
#       Payment_Method  Quantity  Unit_Price  Discount_Percent  Order_Value  \
# 0                UPI         2     7333.01                14     12612.78
# 2         Debit Card         5     4331.51                21     17109.46
# 4             Wallet         5     7138.56                35     23200.32
# 7   Cash on Delivery         5     7481.70                15     31797.22
# 10               UPI         2     6643.50                23     10230.99
#
#     Order_Year Order_Month  Order_Day  Gross_Value  Expected_Order_Value  \
# 0         2025     October  Wednesday     14666.02              12612.78
# 2         2024    November   Thursday     21657.55              17109.46
# 4         2025    November  Wednesday     35692.80              23200.32
# 7         2024    November   Thursday     37408.50              31797.22
# 10        2025     October   Thursday     13287.00              10230.99
#
#     Discount_Amount High_Value_Order Price_Band
# 0           2053.24              Yes       High
# 2           4548.09              Yes     Medium
# 4          12492.48              Yes       High
# 7           5611.28              Yes       High
# 10          3056.01              Yes       High

# %% [markdown]
# ## Task 63
#
# Find rows where Unit_Price is below the 25th percentile.

# %%
df[df['Unit_Price'] < df['Unit_Price'].quantile(0.25)].head()
# Out:
#        Order_ID Order_Date Customer_Segment Region Product_Category  \
# 9   02ORD100137 2024-09-29              Men   West         Footwear
# 11  02ORD100077 2025-08-11             Kids  South            Shirt
# 16  02ORD100281 2024-10-06              Men  South      Accessories
# 26  02ORD100102 2025-08-14            Women  North      Accessories
# 31  02ORD100140 2025-03-17           Unisex  North            Jeans
#
#       Payment_Method  Quantity  Unit_Price  Discount_Percent  Order_Value  \
# 9        Credit Card         2      528.16                30       739.42
# 11               UPI         4      807.35                 6      3035.64
# 16  Cash on Delivery         4      810.04                37      2041.30
# 26            Wallet         1      505.48                10       454.93
# 31            Wallet         2     1512.84                22      2360.03
#
#     Order_Year Order_Month Order_Day  Gross_Value  Expected_Order_Value  \
# 9         2024   September    Sunday      1056.32                739.42
# 11        2025      August    Monday      3229.40               3035.64
# 16        2024     October    Sunday      3240.16               2041.30
# 26        2025      August  Thursday       505.48                454.93
# 31        2025       March    Monday      3025.68               2360.03
#
#     Discount_Amount High_Value_Order Price_Band
# 9            316.90               No        Low
# 11           193.76               No        Low
# 16          1198.86               No        Low
# 26            50.55               No        Low
# 31           665.65               No        Low

# %% [markdown]
# ## Task 64
#
# Find the correlation between Quantity, Unit_Price, Discount_Percent, and Order_Value.

# %%
df[['Quantity','Unit_Price','Discount_Percent','Order_Value']].corr()
# Out:
#                   Quantity  Unit_Price  Discount_Percent  Order_Value
# Quantity          1.000000    0.019301         -0.110871     0.682544
# Unit_Price        0.019301    1.000000          0.050588     0.588576
# Discount_Percent -0.110871    0.050588          1.000000    -0.246881
# Order_Value       0.682544    0.588576         -0.246881     1.000000

# %% [markdown]
# ## Task 65
#
# Export the top 50 highest value orders to a CSV file.

# %%
df.nlargest(50, 'Order_Value').to_csv('top_50_high_value_orders.csv', index=False)
print('CSV exported')

# %% [markdown]
# ## Task 66
#
# Create a bar chart of total Order_Value by Region using Matplotlib.

# %%
region_sales = df.groupby('Region')['Order_Value'].sum().sort_values()
region_sales

region_sales.plot(kind='bar')
plt.title('Total Order Value by Region')
plt.xlabel('Region')
plt.ylabel('Order Value')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Task 67
#
# Create a bar chart of total Quantity sold by Product_Category using Seaborn.

# %%
plt.figure(figsize=(8,4))
sns.barplot(data=df.groupby('Product_Category', as_index=False)['Quantity'].sum(), x='Product_Category', y='Quantity')
plt.xticks(rotation=45)
plt.title('Total Quantity by Product Category')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Task 68
#
# Create a histogram of Unit_Price using Matplotlib.

# %%
plt.figure(figsize=(8,4))
plt.hist(df['Unit_Price'], bins=20)
plt.title('Histogram of Unit Price')
plt.xlabel('Unit Price')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Task 69
#
# Create a histogram of Order_Value with KDE using Seaborn.

# %%
plt.figure(figsize=(8,4))
sns.histplot(df['Order_Value'], bins=20, kde=True)
plt.title('Histogram of Order Value')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Task 70
#
# Create a boxplot of Order_Value by Region.

# %%
plt.figure(figsize=(8,4))
sns.boxplot(data=df, x='Region', y='Order_Value')
plt.xticks(rotation=45)
plt.title('Order Value by Region')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Task 71
#
# Create a boxplot of Unit_Price by Payment_Method.

# %%
plt.figure(figsize=(9,4))
sns.boxplot(data=df, x='Payment_Method', y='Unit_Price')
plt.xticks(rotation=45)
plt.title('Unit Price by Payment Method')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Task 72
#
# Create a countplot of Customer_Segment.

# %%
plt.figure(figsize=(8,4))
sns.countplot(data=df, x='Customer_Segment')
plt.xticks(rotation=45)
plt.title('Customer Segment Count')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Task 73
#
# Create a pie chart of Payment_Method distribution.

# %%
payment_counts = df['Payment_Method'].value_counts()
plt.figure(figsize=(6,6))
plt.pie(payment_counts, labels=payment_counts.index, autopct='%1.1f%%')
plt.title('Payment Method Distribution')
plt.show()

# %% [markdown]
# ## Task 74
#
# Create a line chart of monthly total sales.

# %%
monthly = df.groupby(df['Order_Date'].dt.to_period('M'))['Order_Value'].sum()
monthly.index = monthly.index.astype(str)
plt.figure(figsize=(10,4))
plt.plot(monthly.index, monthly.values, marker='o')
plt.xticks(rotation=45)
plt.title('Monthly Total Sales')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Task 75
#
# Create a heatmap of correlation among numerical columns.

# %%
plt.figure(figsize=(6,4))
sns.heatmap(df[['Quantity','Unit_Price','Discount_Percent','Order_Value']].corr(), annot=True, cmap='Blues')
plt.title('Correlation Heatmap')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Task 76
#
# Create a scatter plot of Unit_Price vs Order_Value.

# %%
plt.figure(figsize=(7,4))
plt.scatter(df['Unit_Price'], df['Order_Value'])
plt.title('Unit Price vs Order Value')
plt.xlabel('Unit Price')
plt.ylabel('Order Value')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Task 77
#
# Create a scatter plot of Quantity vs Order_Value colored by Region using Seaborn.

# %%
plt.figure(figsize=(8,4))
sns.scatterplot(data=df, x='Quantity', y='Order_Value', hue='Region')
plt.title('Quantity vs Order Value by Region')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Task 78
#
# Create a violin plot of Order_Value by Product_Category.

# %%
plt.figure(figsize=(9,4))
sns.violinplot(data=df, x='Product_Category', y='Order_Value')
plt.xticks(rotation=45)
plt.title('Order Value by Product Category')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Task 79
#
# Create a stacked bar style plot of monthly sales by Region.

# %%
monthly_region = df.groupby([df['Order_Date'].dt.to_period('M').astype(str), 'Region'])['Order_Value'].sum().unstack(fill_value=0)
monthly_region.plot(kind='bar', stacked=True, figsize=(10,5))
plt.title('Monthly Sales by Region')
plt.xlabel('Month')
plt.ylabel('Order Value')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Task 80
#
# Create a pairplot for Quantity, Unit_Price, Discount_Percent, and Order_Value.

# %%
sns.pairplot(df[['Quantity','Unit_Price','Discount_Percent','Order_Value']])
plt.show()
